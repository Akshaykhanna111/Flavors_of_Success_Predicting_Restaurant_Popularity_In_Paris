# %%
# Load Packages
#!pip install requests
import requests
import json
import re
import pandas as pd
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', None) 
#!pip install pandas
import os # use this to access your environment variables
#!pip install plotly
import plotly.express as px
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
#!pip install seaborn
import seaborn as sns
import matplotlib.pyplot as plt
#!pip install scipy
from scipy.stats import ttest_ind
import sqlite3
from ast import literal_eval

#!pip install nbformat --upgrade

# %%
final_df = pd.read_csv(r"C:\\Users\\aksha\Documents\\LHL\\LHL Assignments\Week 7\\Tableau Dashboard\\Lat Long POI.csv")
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1693 entries, 0 to 1692
# Data columns (total 95 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Restaurant_Latitude      1693 non-null   float64
#  1   Restaurant_Longitude     1693 non-null   float64
#  2   col                      1693 non-null   object
#  3   Restaurant_Zip_code      1693 non-null   int64
#  4   lodging                  1693 non-null   int64
#  5   airport                  1693 non-null   int64
#  6   library                  1693 non-null   int64
#  7   amusement_park           1693 non-null   int64
#  8   light_rail_station       1693 non-null   int64
#  9   aquarium                 1693 non-null   int64
#  10  bus_station              1693 non-null   int64
#  11  casino                   1693 non-null   int64
#  12  shopping_mall            1693 non-null   int64
#  13  stadium                  1693 non-null   int64
# ...

# %%
result = pd.melt(df, id_vars=['Restaurant_Latitude', 'Restaurant_Longitude', 'Restaurant_Zip_code'], 
                 value_vars=['lodging', 'airport'], 
                 var_name='POI_Type', value_name='Count')

# %%
result.head(5)
# Out:
# Restaurant_Latitude  index           48.7601095 48.7632988 48.76364  \
# 0                        0             2.398427        NaN      NaN
# 1                        1  48.7601095,2.398427        NaN      NaN
# 2                        2                94320        NaN      NaN
# 3                        3                    1        NaN      NaN
# 4                        4                    0        NaN      NaN
#
# Restaurant_Latitude 48.7637913 48.7641819 48.7652302 48.767254 48.76829567  \
# 0                          NaN        NaN        NaN       NaN         NaN
# 1                          NaN        NaN        NaN       NaN         NaN
# 2                          NaN        NaN        NaN       NaN         NaN
# 3                          NaN        NaN        NaN       NaN         NaN
# 4                          NaN        NaN        NaN       NaN         NaN
#
# Restaurant_Latitude 48.7684052 48.7692108 48.7695694 48.7698784 48.7702789  \
# ...
